# %%
import numpy as np
import math
import numpy as np
import matplotlib.pyplot as plt

def function(t):
    a=0.6435
    return 25*math.exp(-t/5)*math.cos(-3*t/a)
t = np.linspace(0, 10, 101)  

exact=[]                      
for i in t:
    exact.append(function(i))

# %%
plt.plot(t, exact, 'r', label='exact(t)')

# %% [markdown]
# # **Euler method**

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x, t, b, k):
    return np.array([x[1], -b*x[1] - k*x[0]])

t = np.linspace(0, 10, 101) 
b = 10/25
k = 226/25
y0 = np.array([0,5])

def rungekutta1(f, y0, t, args=()):
    n = len(t)
    y = np.zeros((n, len(y0)))
    y[0] = y0
    for i in range(n - 1):
        y[i+1] = y[i] + (t[i+1] - t[i]) * f(y[i], t[i], *args)
    return y

rk1 = rungekutta1(f, y0, t, args=(b, k))

# %%
plt.plot(t, exact, 'r', label='exact(t)')
plt.plot(t, rk1[:, 0], 'b', label='x(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
err=[]
for i in range(len(t)):
  err.append(exact[i]-rk1[:,0][i])

plt.plot(t, err, 'b', label='err')

# %%
Sum=0
ab=0
for i in range(len(t)):
  Sum=Sum=+ err[i]**2
  ab=ab + abs(err[i])

RMSE=math.sqrt(Sum)/len(t)
MAE=ab/len(t)

print("RMSE = ",RMSE)
print("MAE = ",MAE)
# Out:
# RMSE =  0.16168076828118222
# MAE =  9.25373956836818

# %% [markdown]
# # **odeint() method**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

def f(x, t, b, k):
    return np.array([x[1], -b*x[1] - k*x[0]])

t = np.linspace(0, 10, 101) 
b = 10/25
k = 226/25
y0 = np.array([0,5])


odeintsol = odeint(f, y0, t, args=(b, k))

plt.plot(t, odeintsol[:, 0], 'b', label='I(t)')
plt.plot(t, exact, 'r', label='TRUE(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
err=[]
for i in range(len(t)):
  err.append(exact[i]-odeintsol[:,0][i])


plt.plot(t, err, 'b', label='Q(t)')

# %%
Sum=0
ab=0
for i in range(len(t)):
  Sum=Sum=+ err[i]**2
  ab=ab + abs(err[i])

RMSE=math.sqrt(Sum)/len(t)
MAE=ab/len(t)

print("RMSE = ",RMSE)
print("MAE = ",MAE)
# Out:
# RMSE =  0.02712952374744634
# MAE =  6.993202990429612
